# %%
# %matplotlib notebook
from functions import *

# %%
shape = (100, 100)

# %%
ffts = np.fromfile("fft.dt", dtype=np.complex64)
ffts = ffts.reshape((4, *shape))

# %%
tlen = 10000
dms = np.fromfile("dms.dt", dtype=np.float32)
dms = dms.reshape((tlen, *shape, 15))

# %%
xidx = 30
yidx = 30
trace1 = dms[:, xidx, yidx, 9] + dms[:, xidx, yidx, 14]
trace2 = dms[:, xidx, yidx, 4] + dms[:, xidx, yidx, 14]
sm2re = dms[:, xidx, yidx, 0] + dms[:, xidx, yidx, 10]
sm2im = dms[:, xidx, yidx, 3] + dms[:, xidx, yidx, 13]

sm1re = dms[:, xidx, yidx, 1] + dms[:, xidx, yidx, 6]
sm1im = dms[:, xidx, yidx, 7] + dms[:, xidx, yidx, 12]
plot_sigmas(trace1, trace2, sm1re, sm1im, sm2re, sm2im)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
plot_maps(np.abs(ffts)**2)
# Out:
# <img src="data:image/png;base64,..." width="900">
